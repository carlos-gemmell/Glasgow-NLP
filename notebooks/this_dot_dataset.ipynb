# %% [markdown]
# # Youtube dataset extraction pipeline prototype
#
# Links to example channel videos:
# - The coding train (highest quality): 14
#     - https://www.youtube.com/watch?v=dSK-MW-zuAc
#     - https://www.youtube.com/watch?v=17WoOqgXsRM&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH
#     - https://www.youtube.com/watch?v=LG8ZK-rRkXo&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=2
#     - https://www.youtube.com/watch?v=AaGK-fj-BAM&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=3
#     - https://www.youtube.com/watch?v=KkyIDI6rQJI&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=4
#     - https://www.youtube.com/watch?v=biN3v3ef-Y0&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=5
#     - https://www.youtube.com/watch?v=jxGS3fKPKJA&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=6
#     - https://www.youtube.com/watch?v=l8SiJ-RmeHU&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=7
#     - https://www.youtube.com/watch?v=dncudkelNxw&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=8
#     - https://www.youtube.com/watch?v=FGAwi7wpU8c&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=9
#     - https://www.youtube.com/watch?v=HyK_Q5rrcr4&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=10
#     - https://www.youtube.com/watch?v=D8UgRyRnvXU&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=11
#     - https://www.youtube.com/watch?v=D8UgRyRnvXU&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=12
#     - https://www.youtube.com/watch?v=D8UgRyRnvXU&list=PLRqwX-V7Uu6ZiZxtDDRCi6uhfTH4FilpH&index=13
# - Derek Bannas: 20
#     - https://www.youtube.com/watch?v=IyDVvGmzTlo
#     - https://www.youtube.com/watch?v=22QAmVctAMc&t=922s
#     - https://www.youtube.com/watch?v=x51y0jhTqCE
#     - https://www.youtube.com/watch?v=GOE1IMF5J08
#     - https://www.youtube.com/watch?v=zeTPUdhfJOk
#     - https://www.youtube.com/watch?v=GDTHmH9mZWA
#     - https://www.youtube.com/watch?v=R5MqjOoLGtU&t=9s
#     - https://www.youtube.com/watch?v=M8dSn4kZlCw
#     - https://www.youtube.com/watch?v=rex2_9YBKAE
#     - https://www.youtube.com/watch?v=QDp8BZbwOqk
#     - https://www.youtube.com/watch?v=2DSx_QPTo3U
#     - https://www.youtube.com/watch?v=HWuU5ly0taA
#     - https://www.youtube.com/watch?v=xI7BI30rpRw
#     - https://www.youtube.com/watch?v=H1elmMBnykA&t=2208s
#     - https://www.youtube.com/watch?v=6y0bp-mnYU0&t=766s
#     - https://www.youtube.com/watch?v=NihZYkNpslE
#     - https://www.youtube.com/watch?v=4lJf0aQQpa4&t=1448s
#     - https://www.youtube.com/watch?v=1b2QHI6eETM
#     - https://www.youtube.com/watch?v=QO_Jlz1qpDw
#     - https://www.youtube.com/watch?v=CF9S4QZuV30
# - The new boston
#     - https://www.youtube.com/watch?v=IW2M8G8uJ6o&list=PL6gx4Cwl9DGBMdkKFn3HasZnnAqVjzHn_&index=7
#     - https://www.youtube.com/watch?v=_D2w0voFlEk&list=PL6gx4Cwl9DGBMdkKFn3HasZnnAqVjzHn_&index=14
#     - https://www.youtube.com/watch?v=54aol-U_1es&list=PL6gx4Cwl9DGBMdkKFn3HasZnnAqVjzHn_&index=15
#     - https://www.youtube.com/watch?v=pYOltVz7kL0&list=PL6gx4Cwl9DGBMdkKFn3HasZnnAqVjzHn_&index=13
# - Engineer man:
#     - https://www.youtube.com/watch?v=lbbNoCFSBV4
#     - https://www.youtube.com/watch?v=rbasThWVb-c
#     - https://www.youtube.com/watch?v=UOuH8IVFAGk&list=PLlcnQQJK8SUj5vlKibv8_i42nwmxDUOFc&index=2
#     - https://www.youtube.com/watch?v=C6LVvQ_stzk&list=PLlcnQQJK8SUjW_HiBWhZ_XOfCq9Hu0aeY&index=9
# - ProgrammingKnowledge: 14
#     - https://www.youtube.com/watch?v=qBpB_ve4sWo&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=15
#     - https://www.youtube.com/watch?v=7P7KGVwMSIs&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=16
#     - https://www.youtube.com/watch?v=u0ylwy4Mv7A&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=23
#     - https://www.youtube.com/watch?v=4qw5atfs_As&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=24
#     - https://www.youtube.com/watch?v=EHzKEh74sJI&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=25
#     - https://www.youtube.com/watch?v=3nrm-aTCwdQ&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=26
#     - https://www.youtube.com/watch?v=NL04MIIP0P0&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=28
#     - https://www.youtube.com/watch?v=oE_dWWWqxQ0&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=29
#     - https://www.youtube.com/watch?v=TFLo9m0jFEg&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=31
#     - https://www.youtube.com/watch?v=aQz9_V8aoEw&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=32
#     - https://www.youtube.com/watch?v=m6hhUBXcA-E&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=34
#     - https://www.youtube.com/watch?v=o_GrDGjRUuQ&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=35
#     - https://www.youtube.com/watch?v=aBexJgZ6GjI&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=36
#     - https://www.youtube.com/watch?v=lhiH-6ygGl8&list=PLS1QulWo1RIYt4e0WnBp-ZjCNq8X0FX0J&index=37
# - LearnCode.academy
# - Codecourse
# - Telusko
# - Neil Rowe
# - Jake Wright: 4
#     - https://www.youtube.com/watch?v=C8LgvuEBraI
#     - https://www.youtube.com/watch?v=LvgVSSpwND8
#     - https://www.youtube.com/watch?v=Ukg_U3CnJWI&t=143s
#     - https://www.youtube.com/watch?v=ZdP0KM49IVk (rough video quality)

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
from pytesseract import Output
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
from pytube import YouTube
from youtube_transcript_api import YouTubeTranscriptApi
from src.FrameExtractor import FrameExtractor
import tqdm.notebook as tqdm 
import json
from pprint import pprint
import os
import difflib

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%capture
print(pytesseract.image_to_data(Image.open('images/daniel_coding.png')))

# %%
transcript = YouTubeTranscriptApi.get_transcript("H81Tdrmz2LA")
transcript[:10]
# Out:
# [{'text': 'all right this is my first coding', 'start': 0.17, 'duration': 5.5},
#  {'text': "challenge that I'm going to attempt in",
#   'start': 3.09,
#   'duration': 5.37},
#  {'text': 'JavaScript using 3d rendering I am',
#   'start': 5.67,
#   'duration': 4.17},
#  {'text': 'currently working on a set of tutorials',
#   'start': 8.46,
#   'duration': 4.08},
#  {'text': 'about WebGL in p5.js I will link to',
#   'start': 9.84,
#   'duration': 4.14},
#  {'text': 'those from this coding challenges video',
#   'start': 12.54,
#   'duration': 5.22},
#  {'text': 'description but I bees and bombs on',
#   'start': 13.98,
#   'duration': 6.09},
#  {'text': "Twitter I highly recommend if you're",
#   'start': 17.76,
#   'duration': 4.13},
#  {'text': 'interested in looking for like really',
#   'start': 20.07,
#   'duration': 4.52},
#  {'text': 'geometric algorithmic mathematical',
#   'start': 21.89,
#   'duration': 4.809}]

# %%
video = YouTube('https://www.youtube.com/watch?v=H81Tdrmz2LA')

# %%
video.streams.filter(file_extension = "mp4").all()
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">,
#  <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">,
#  <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">,
#  <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">,
#  <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">,
#  <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">,
#  <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">,
# ...

# %%
video.captions

# %%
video.streams.get_by_itag(136).download('images')
# Out:
# '/nfs/phd_by_carlos/notebooks/images/Coding Challenge 86 Cube Wave by Bees and Bombs.mp4'

# %%
fe = FrameExtractor('images/Coding Challenge 86 Cube Wave by Bees and Bombs.mp4')

# %%
fe.get_video_duration()
# Out:
# Duration: 0:30:08.533333

# %%
times = [t["start"] for t in transcript]

# %%
frames = fe.times2frames(times)

# %%
def process_video(video_id, data_dir="datasets/this_dot_dataset", frame_context=1):
    print("Downloading video...")
    video = YouTube(f'https://www.youtube.com/watch?v={video_id}')
    title = video.title
    dest_path = os.path.join(data_dir,title)
    if dest_path is None:
        dest_path = os.getcwd()
    else:
        if not os.path.isdir(dest_path):
            os.makedirs(dest_path)
            print(f'Created the following directory: {dest_path}')
    
    video_path = video.streams.get_by_itag(136).download(dest_path)
    print("Downloading transcript...")
    transcript = YouTubeTranscriptApi.get_transcript("H81Tdrmz2LA")
    fe = FrameExtractor(video_path)
    frames = []
    for t in transcript:
        frame = fe.times2frames([t["start"]])[0]
        surrounding_frames = list(range(frame-frame_context, frame+frame_context+1))
        t["frame"] = frame
        t["surrounding_frames"] = surrounding_frames
        frames += surrounding_frames
    print("Extracting frames from transcript...")
    fe.extract_specific_frames(frames, img_name="frame", dest_path=os.path.join(dest_path,"frames"))
    print("performing OCR on frames...")
    for i, t in tqdm.tqdm(enumerate(transcript)):
        surrounding_text = []
        for frame in tqdm.tqdm(t["surrounding_frames"], leave=False):
            image = cv2.imread(f"{dest_path}/frames/frame_{frame}.jpg")
            try:
                text = pytesseract.image_to_string(image)
                surrounding_text.append(text)
            except Exception as e:
                print(f"Exception during OCR at frame {frame} for: {title}")
                print(e)
        t["surrounding_text"] = surrounding_text
        # save the json every 30 steps just in case
        if i % 30 == 0 or i == len(transcript)-1:
            with open(os.path.join(dest_path,"transcript_OCR.json"), 'w') as f:
                json.dump(transcript, f)
    return transcript

# %%
t_script = process_video("H81Tdrmz2LA", data_dir="datasets/this_dot_dataset", frame_context=1)
# Out:
# ...
# Extracting frames from transcript...
# performing OCR on frames...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-1b78644ab907> in <module>
# ----> 1 t_script = process_video("H81Tdrmz2LA", data_dir="datasets/this_dot_dataset", frame_context=1)
#
# <ipython-input-23-8475a6eeddca> in process_video(video_id, data_dir, frame_context)
#      30             image = cv2.imread(f"{dest_path}/frames/frame_{frame}.jpg")
#      31             try:
# ---> 32                 text = pytesseract.image_to_string(image)
#      33                 surrounding_text.append(text)
#      34             except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     372         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# ...

# %%
with open('datasets/this_dot_dataset/Coding Challenge #86: Cube Wave by Bees and Bombs/transcript_OCR.json', 'r') as f:
    t_script = json.load(f)

# %%
for t in t_script[36:40]:
    print(t["text"])
    print(t["start"])
    print(t["surrounding_text"][1])
    print("----------")
# Out:
# have a variable I'm gonna call that
# 83.64
# 5
#
# function setup() {
# createCanvas(400, 400);
# e
#
# function draw() {| £
#
# i
# ----------
# variable angle and I'm gonna stick I'm
# 86.79
# Fe io 23
#
# let angle|
#
# function setup() {
# createCanvas(400, 400);
#
# +
#
# function draw() {
# ----------
# not gonna I could add angle mode degrees
# 89.61
# 10
#
# ¥SDO%S
#
# let angle = Q;
#
# function setup() {
# createCanvas(400, 400);
#
# i
#
# function draw() {
# ----------
# to think in terms of degrees but I'm
# 92.04
# let angle =
# function setup() {
#
# createCanvas(400, 400);
# +
#
# function draw() {
# ----------

# %%
start = t_script[36]["surrounding_text"][1]
finish = t_script[38]["surrounding_text"][1]
print(start)
print("#########")
print(finish)
# Out:
# 5
#
# function setup() {
# createCanvas(400, 400);
# e
#
# function draw() {| £
#
# i
# #########
# 10
#
# ¥SDO%S
#
# let angle = Q;
#
# function setup() {
# createCanvas(400, 400);
#
# i
#
# function draw() {

# %%
from textblob.classifiers import NaiveBayesClassifier

train = [
    ('createCanvas(400, 400);', True),
    ('let angle = 0;', True),
    ('function setup() {', True),
    ('{', True),
    ("}", True),
    ('10', False),
    ('1', False),
    ("2", False),
    ('3', False),
    ('e', False)
]
cl = NaiveBayesClassifier(train)

# %%
cl.classify("var foo = 4")
# Out:
# False

# %%
def explorer_cls(s):
    print(s)
    return cl.classify(s)

# %%
from fuzzysearch import find_near_matches, find_near_matches_with_ngrams
find_near_matches_with_ngrams(start, finish, max_distance)

# %%
s = SequenceMatcher(cl.classify, start, finish)
blocks = s.get_matching_blocks()
print(blocks)
for block in blocks[:-1]:
    print("Matching:")
    print(start[block.a:block.a+block.size])
    print("-------------")
    print(finish[block.b:block.b+block.size])
    print("##################")
# Out:
# ;
#
# function setup() {
# createCanvas(40
# ;
#
# function setup() {
# createCanvas(400
# 0, 40
# 0, 400
# [Match(a=1, b=26, size=45), Match(a=47, b=73, size=19), Match(a=72, b=92, size=0)]
# Matching:
#
#
# function setup() {
# createCanvas(400, 400);
#
# -------------
#
#
# function setup() {
# createCanvas(400, 400);
#
# ##################
# Matching:
#
#
# function draw() {
# -------------
#
#
# function draw() {
# ##################

# %%
for l in difflib.unified_diff(start, finish):
    print(l)
# Out:
# ---
#
# +++
#
# @@ -1,4 +1,29 @@
#
# -5
# +1
# +0
# +
#
# +
#
# +¥
# +S
# +D
# +O
# +%
# +S
# +
#
# +
#
# +l
# +e
# +t
# +
# +a
# +n
# +g
# +l
# +e
# +
# +=
# +
# +Q
# +;
#
#
#
#
#  f
# @@ -44,7 +69,8 @@
#
#  )
#  ;
#
#
# -e
# +
#
# +i
#
#
#
#
#  f
# @@ -64,9 +90,3 @@
#
#  )
#
#  {
# -|
# -
# -£
# -
#
# -
#
# -i

# %%
from diff_match_patch import diff_match_patch
dmp = diff_match_patch()
patches = dmp.patch_make(start, finish)
diff = dmp.patch_toText(patches)
print(diff)
new_text, _ = dmp.patch_apply(patches, start)
new_text
# Out:
# @@ -1,5 +1,30 @@
# -5
# +10%0A%0A%C2%A5SDO%25S%0A%0Alet angle = Q;
#  %0A%0Afu
# @@ -64,17 +64,18 @@
#  , 400);%0A
# -e
# +%0Ai
#  %0A%0Afuncti
# @@ -89,10 +89,4 @@
#  () %7B
# -%7C %C2%A3%0A%0Ai
# '10\n\n¥SDO%S\n\nlet angle = Q;\n\nfunction setup() {\ncreateCanvas(400, 400);\n\ni\n\nfunction draw() {'

# %%
result = list(difflib.Differ().compare(start.splitlines(1), finish.splitlines(1)))
result
# Out:
# ['- 5\n',
#  '+ 10\n',
#  '+ \n',
#  '+ ¥SDO%S\n',
#  '+ \n',
#  '+ let angle = Q;\n',
#  '  \n',
#  '  function setup() {\n',
#  '  createCanvas(400, 400);\n',
#  '- e\n',
#  '  \n',
#  '- function draw() {| £\n',
#  '+ i\n',
#  '  \n',
#  '- i',
#  '+ function draw() {']

# %%
for r in result:
    if (r[0] == "+" or r[0] == " "):
        print(r[2:])
# Out:
# 10
#
#
#
# ¥SDO%S
#
#
#
# let angle = Q;
#
#
#
# function setup() {
#
# createCanvas(400, 400);
#
#
#
# i
#
#
#
# function draw() {

# %%
for r in result:
    if (r[0] == "+" or r[0] == " ") and cl.classify(r[2:]):
        print(r[2:])
# Out:
# let angle = Q;
#
# function setup() {
#
# createCanvas(400, 400);
#
# function draw() {

# %%
fe.extract_frames_at_time(times, img_name="challenge_86", dest_path="images/frames")

# %%
554 477 568 515

# %%
def show_image(path):
    image = cv2.imread(path)
    height, width, channels = image.shape
    plt.rcParams['figure.figsize'] = [15, 7.5]
    plt.imshow(image[height-515:height-477,554:568])
    plt.show()
    plt.imshow(image)
    plt.show()
plt.show()
frame = 182
show_image(f'images/frames/challenge_86_{frame}.jpg')

# %%
def read_image(path):
    image = cv2.imread(path)
    custom_oem_psm_config = r'--psm 1 --load_system_dawg False'
    text = pytesseract.image_to_string(image)
    d = pytesseract.image_to_boxes(image, output_type=Output.DICT)
    print(text)
    print("###########")
    print(d.keys())
    heights = []
    widths = []
    xs = []
    ys = []
    for i, (c,l,b,r,t) in enumerate(zip(d["char"], d['left'], d['bottom'], d['right'], d['top'])):
#         print(c,l,b,r,t)
        height, width, channels = image.shape
        char_height = t-b
        char_width = r-l
        char_center_x = l + char_width/2
        char_center_y = height-t + char_height/2
        if char_height > 35:
            print(c,l,b,r,t)
        else:
            image[height-t:height-b,l:r] -= np.array([80,80,80],dtype='uint8')
        heights.append(char_height)
        widths.append(char_width)
        xs.append(char_center_x)
        ys.append(char_center_y)
    
    points = np.array(list(zip(xs, ys)))
    
    plt.rcParams['figure.figsize'] = [30, 15]
    plt.imshow(image)
    plt.show()
    print("widths:",np.average(widths))
    print("heights:",np.average(heights))
    return points, np.average(widths), np.average(heights)

# %% [markdown]
# ### how to get bounding box from tesseract
# [height-top:height-bottom,left:right]

# %%
points, widths, heights = read_image(f'images/frames/challenge_86_{frame}.jpg')
# Out:
# 10 cre Lea
# let w = 24;
# let magicangle;
#
# } attire sel Taam nt
# createCanvas(400, 400, WEBGL);
# i
#
# function draw() {
# background(10Q) ;
# (lata Te OH
#
# fag] M 00) Pol Po
# rotateX(-QUARTER_PI);
# rotateY (arc)
# ###########
# dict_keys(['char', 'left', 'bottom', 'right', 'top', 'page'])
# a 554 477 568 515
# ~ 0 0 375 720
# widths: 13.037037037037036
# heights: 21.944444444444443

# %%
import numpy as np
from scipy.optimize import leastsq, minimize

def get_spot_grid(x_step, y_step, x, y, x_dim=40, y_dim=20):
    # [x,y,[x,y]]
    raster_grid= np.array(np.meshgrid(np.arange(x_dim)*x_step+x, np.arange(y_dim)*y_step+y)) \
            .transpose([1,2,0]).reshape((x_dim*y_dim,2))
    return raster_grid


def get_mean_distance(raster_grid, data_grid):
#     loss = np.mean(np.sqrt((grid_pred[:data_grid.shape[0]] - data_grid)**2))
    num_data = data_grid.shape[0]
    num_grid_data = raster_grid.shape[0]
    tiled_points = np.tile(data_grid,(num_grid_data,1,1)).reshape((num_grid_data,num_data,2)).transpose([1,0,2])
    tiled_grid = np.tile(raster_grid,(num_data,1,1))
#     print(tiled_points)
#     print(tiled_grid)
#     print(tiled_grid-tiled_points)
#     print(np.power(tiled_grid-tiled_points,2))
#     print(np.sum(np.power(tiled_grid-tiled_points,2),axis=-1))
#     print(np.sqrt(np.sum(np.power(tiled_grid-tiled_points,2),axis=-1)))
#     print(np.min(np.sqrt(np.sum(np.power(tiled_grid-tiled_points,2),axis=-1)),axis=1))
    loss = np.mean(np.min(np.sqrt(np.sum(np.power(tiled_grid-tiled_points,2),axis=-1)),axis=1))
    return loss


def err_func(params, data_grid):
    x_step, y_step, x, y = params
    raster_grid = get_spot_grid(x_step, y_step, x, y)
    loss = get_mean_distance(raster_grid, data_grid)
#     loss += np.abs(x_step - y_step*0.43)
    return loss

# %%
err_func((x_step, y_step, x_pos, y_pos), points)
# Out:
# 11.122358964774794

# %%
err_func((15.6, 38.5, 547, 75), points)
# Out:
# 8.08958515603505

# %%
p_xs = np.sort(points[:,1])
p_xs
# Out:
# array([ 68. ,  68. ,  68. ,  69. ,  70.5,  70.5,  70.5,  73.5, 107. ,
#        107. , 107. , 107.5, 108. , 109. , 109.5, 109.5, 145. , 145. ,
#        145.5, 146. , 148. , 148. , 148.5, 148.5, 148.5, 148.5, 148.5,
#        150. , 151. , 151. , 223. , 223. , 223. , 223.5, 223.5, 224. ,
#        225.5, 225.5, 225.5, 225.5, 225.5, 225.5, 225.5, 225.5, 225.5,
#        226. , 261.5, 261.5, 261.5, 261.5, 261.5, 261.5, 261.5, 262. ,
#        262. , 262. , 262. , 262. , 262. , 262. , 262. , 262.5, 264. ,
#        264. , 264. , 264.5, 264.5, 264.5, 264.5, 264.5, 264.5, 264.5,
#        271.5, 271.5, 300.5, 360. , 377.5, 377.5, 377.5, 377.5, 378. ,
#        378. , 378. , 380. , 380. , 380. , 380. , 380.5, 380.5, 380.5,
#        380.5, 416. , 416. , 416.5, 416.5, 416.5, 416.5, 416.5, 417.5,
#        418.5, 418.5, 419. , 419. , 419. , 419. , 419. , 421.5, 455. ,
#        455.5, 456. , 456. , 457.5, 457.5, 457.5, 457.5, 459. , 571. ,
# ...

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
X = np.array(list(zip(p_xs,np.zeros(len(p_xs)))), dtype=np.int)
bandwidth = estimate_bandwidth(X, quantile=0.03)
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

x_clusters = []
for k in range(n_clusters_):
    my_members = labels == k
    print ("cluster {0}: {1}".format(k, X[my_members, 0]))
    avg_x = np.average(X[my_members, 0])
    x_clusters.append(avg_x)
    
    
x_clusters = np.sort(np.array(x_clusters))
np.average(x_clusters[1:] - x_clusters[:-1])
# Out:
# cluster 0: [261 261 261 261 261 261 261 262 262 262 262 262 262 262 262 262]
# cluster 1: [609 609 609 609 609 609 609 609 609 610 610 610 610 610]
# cluster 2: [225 225 225 225 225 225 225 225 225 226]
# cluster 3: [264 264 264 264 264 264 264 264 264 264]
# cluster 4: [648 648 648 649 649 650 650 650 650 651 651]
# cluster 5: [571 571 571 571 571 572 572 572 572 573 573 573]
# cluster 6: [416 416 416 416 416 416 416 417]
# cluster 7: [380 380 380 380 380 380 380 380]
# cluster 8: [418 418 419 419 419 419 419]
# cluster 9: [377 377 377 377 378 378 378]
# cluster 10: [148 148 148 148 148 148 148]
# cluster 11: [611 611 612 612 612 612]
# cluster 12: [455 455 456 456 457 457 457 457]
# cluster 13: [223 223 223 223 223 224]
# cluster 14: [107 107 107 107]
# cluster 15: [145 145 145 146]
# cluster 16: [108 109 109 109]
# cluster 17: [69 70 70 70]
# cluster 18: [68 68 68]
# cluster 19: [150 151 151]
# cluster 20: [271 271]
# cluster 21: [720]
# cluster 22: [623]
# cluster 23: [580]
# ...

# %%
[1,2,3]
# Out:
# [1, 2]

# %%
xe = np.array([1,  2,  1,  2]).reshape(2, 2)
ye = np.array([1, 2, 2, 1]).reshape(2, 2)

start_center = np.mean(points, axis=0)
start_top_left = start_center - np.array([widths*20, heights*10])

start_x0 = (widths, heights, start_center[0], start_center[1])
print(start_x0)

# leastsq(err_func, x0=(19, 12, 5, 0), args=(xe, ye))
result = minimize(err_func, x0=start_x0, args=(points), method='Powell',
                 options={'xtol': 0.000001, 'ftol': 0.000001})
print(result)
x_step, y_step, x_pos, y_pos = result.x
# Out:
# (13.037037037037036, 21.944444444444443, 706.1543209876543, 368.8425925925926)
#    direc: array([[-3.53983021e-02, -5.06214500e-02,  6.87769602e-01,
#          2.60583285e-01],
#        [-7.23909233e-03, -3.83966234e-04,  6.69495982e-02,
#          5.77364468e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00],
#        [-3.23329822e-03,  1.52923347e-02,  5.11139830e-02,
#         -2.08095201e-01]])
#      fun: 9.031719368275263
#  message: 'Optimization terminated successfully.'
#     nfev: 706
#      nit: 11
#   status: 0
#  success: True
#        x: array([ 15.77043765,  31.60898566, 528.80977831,  40.8171999 ])

# %%
grid_points = get_spot_grid(15.727,  38.61 , 497.979,  -7.065)
grid_points[:4]
# Out:
# array([[497.979,  -7.065],
#        [513.706,  -7.065],
#        [529.433,  -7.065],
#        [545.16 ,  -7.065]])

# %%
grid_points = get_spot_grid(x_step, y_step, x_pos, y_pos)

# %%
err_func((13.0, 21.0, 30, 500), points)
# Out:
# 270.61914906287615

# %%
err_func((15.727,  38.61 , 497.979,  -7.065), points)
# Out:
# 5.813210010495252

# %%
new_img = cv2.imread(f'images/frames/challenge_86_{frame}.jpg')
grid_points = [[x,y] for x,y in grid_points if x<1250 and y<720]
for x,y in grid_points:
    new_img[int(y)-1:int(y)+1,int(x)-1:int(x)+1] = np.array([0,255,0],dtype='uint8')
plt.imshow(new_img)
plt.show()
