# %% [markdown]
# # Relevance Transformer Experiments

# %%
from src.autoregressive_transformer import AutoregressiveTransformer
from src.dataset_loaders import SRC_TGT_pairs
from src.vocab_classes import Shared_Vocab, BERT_Vocab
from src.useful_utils import string_split_v3, string_split_v2, string_split_v1
from src.trainers import Model_Trainer
from src.retrieval import PyLuceneRetriever, OracleBLEURetriever
import torch
import torch.nn as nn
from torchtext.data import Field, BucketIterator
import numpy as np
import dotmap
from collections import Counter
# %load_ext autoreload
# %autoreload 2

# %%
# hyperparams
src_train_fp = "datasets/CoNaLa/conala-train.src"
tgt_train_fp = "datasets/CoNaLa/conala-train.tgt"
src_test_fp = "datasets/CoNaLa/conala-test.src"
tgt_test_fp = "datasets/CoNaLa/conala-test.tgt"
max_seq_len = 75
vocab_size = 850
embed_dim = 512
att_heads = 4
layers = 2
batch_size = 32
dim_feedforward = 1024
# model_save_file = "django-tiny-transformer-custom-tok-50-seq-len-850-vocab/model_file_step_495000.torch"
model_save_file = "conala-tiny-transformer-custom-tok-75-seq-len-850-vocab/model_file_step_495000.torch"
output_dir = "conala-retrieval-testing"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_samples = SRC_TGT_pairs(src_train_fp, tgt_train_fp, max_seq_len=max_seq_len).samples
test_samples = SRC_TGT_pairs(src_test_fp, tgt_test_fp, max_seq_len=max_seq_len).samples

vocab = Shared_Vocab(train_samples, vocab_size, string_split_v3, use_OOVs=True)


model = AutoregressiveTransformer(vocab_size=vocab_size, embed_dim=embed_dim, att_heads=att_heads, \
                                  layers=layers, dim_feedforward=dim_feedforward, max_seq_length=max_seq_len).to(device)
test_dataset = model.data2dataset(test_samples, vocab)
test_iterator = BucketIterator(
    test_dataset,
    batch_size = batch_size,
    sort=True,
    sort_key = model.sample_order_fn,
    device = device)

model.load_model(model_save_file)
trainer = Model_Trainer(model, vocab, test_iterator=test_iterator)
# Out:
# 'output_dir' not defined, training and model outputs won't be saved.

# %%
outputs = trainer.evaluate(test_iterator)
avg_BLEU = np.average([out["BLEU"] for out in outputs])
print(f"Small Copy Transformer BLEU: {avg_BLEU*100:.2f}")
# Out:
# HBox(children=(IntProgress(value=0, max=16), HTML(value='')))
# Small Copy Transformer BLEU: 21.80

# %% [markdown]
# ## Retrieval decoding

# %%
tgt_train_samples = [tgt for src, tgt in train_samples]

counts = Counter(string_split_v3(" ".join(tgt_train_samples))).most_common(30)
stop_words = [x[0] for x in counts]

# %%
def retrieval_output_nudging_creator(oracle=False, relevance_interpol=0.0005, k_docs=5, k_words=10, peak_scaling_factor=10.0, verbose=False):
    src_train_samples = [src for src, tgt in train_samples]
    tgt_train_samples = [tgt for src, tgt in train_samples]
    if oracle:
        retriever = OracleBLEURetriever(ids_to_keep=k_docs)
        retriever.add_multiple_docs(train_samples)
    else:
        retriever = PyLuceneRetriever()
        retriever.add_multiple_docs(src_train_samples)
    
    counts = Counter(string_split_v3(" ".join(tgt_train_samples))).most_common(30)
    stop_words = [x[0] for x in counts]
    
    def nudge_fn(last_token_log_probs, single_decoder_input, batch_encoder_ids, batch_decoder_truth_ids, OOVs):
        OOVs = OOVs.cpu().tolist()
        src_sent = vocab.decode_input(batch_encoder_ids, OOVs, copy_marker="")
        tgt_sent = vocab.decode_output(batch_decoder_truth_ids, OOVs, copy_marker="")
        current_pred = vocab.decode_output(single_decoder_input, OOVs, copy_marker="")
        top_5_ids = torch.argsort(last_token_log_probs.cpu(), descending=True)[:5]
        top_5_words = [vocab.decode_output([idx], OOVs, copy_marker="") for idx in top_5_ids]
        if verbose:
            print("## DECODE STEP ##")
            print(f"SRC input:      {src_sent}")
            print(f"TGT truth:      {tgt_sent}")
            print(f"decoded so far: {current_pred}")
            print(f"top words     : {' | '.join(top_5_words)}")
            print()
        if oracle:
            doc_ranking = retriever.search(src_sent, tgt_sent, max_retrieved_docs=k_docs)
        else:
            doc_ranking = retriever.search(src_sent, max_retrieved_docs=k_docs)
            
        retrieved_samples = [(tgt_train_samples[doc_id], score) for doc_id, score in doc_ranking]
        scoring_dict = {}
        for sample, score in retrieved_samples:
            if verbose:
                print(f"DOC: {sample}")
            sample_toks = string_split_v3(sample)
            for tok in sample_toks:
                if tok in scoring_dict:
                    scoring_dict[tok] += (peak_scaling_factor * score)/len(sample_toks)
                else:
                    scoring_dict[tok] = (peak_scaling_factor * score)/len(sample_toks)
        top_retrieved_words = [tok for tok in sorted(scoring_dict.items(), key=lambda item: -item[1]) if tok[0] not in stop_words][:k_words]
        if verbose:
            print(f"RETRIEVAL top words: {[tok for tok, score in top_retrieved_words]}")
            print()
            print()
        top_retrieved_ids = [(vocab.encode_output(tok, OOVs)[0], score) for tok, score in top_retrieved_words]
        top_retrieved_ids = [(i, s) for i, s in top_retrieved_ids if i != vocab.UNK]
        
        relevance_vector = torch.zeros_like(last_token_log_probs).fill_(-5000.0)
        for idx, score in top_retrieved_ids:
            if idx not in single_decoder_input:
                relevance_vector[idx] = score
        relevance_vector.softmax(-1)
        
        if top_5_ids[0] == vocab.EOS:
            new_probs = last_token_log_probs
        else:
            new_probs = (1-relevance_interpol) * last_token_log_probs + relevance_interpol * relevance_vector
        
        new_top_pred = torch.argmax(new_probs)
        if top_5_ids[0] != new_top_pred:
            print("Relevance impact:")
            print(f"TGT truth:      {tgt_sent}")
            print(f"decoded so far: {current_pred}")
            print(f"RETRIEVAL top words: {[tok for tok, score in top_retrieved_words][:]}")
            print(f"Prerdicted {vocab.decode_output([new_top_pred], OOVs)} over {top_5_words[0]}")
            print()
            
        return new_probs
    
    return nudge_fn

# %%
retrieval_decoder_fn = retrieval_output_nudging_creator(oracle=False, verbose=False)

model = AutoregressiveTransformer(vocab_size=vocab_size, embed_dim=embed_dim, att_heads=att_heads, \
                                  layers=layers, dim_feedforward=dim_feedforward, max_seq_length=max_seq_len, \
                                  output_nudge_fn=retrieval_decoder_fn).to(device)
model.eval()
model.load_model(model_save_file)
# Out:
# JVM Running

# %%
src = "plot dataframe ` df ` without a legend "
src_ids, OOVs = vocab.encode_input(src)

tgt = "df . plot ( legend = False ) "
tgt_ids = vocab.encode_output(tgt, OOVs)

batch = dotmap.DotMap()
batch.src = torch.tensor([vocab.SOS] + src_ids + [vocab.EOS]).unsqueeze(1).to(device)
batch.tgt = torch.tensor([vocab.SOS] + tgt_ids + [vocab.EOS]).unsqueeze(1).to(device)
batch.OOVs = torch.tensor(OOVs).unsqueeze(1).to(device)

# OVERRIDE
# batch = next(iter(test_iterator))

model.eval_step(batch, vocab)
# Out:
# [{'BLEU': 0.139434582433844,
#   'SRC': 'plot dataframe ` df ` without a legend',
#   'TGT': 'df . plot ( legend = False )',
#   'PRED': 'df . <unk> ( )'}]

# %%
trainer = Model_Trainer(model, vocab, test_iterator=test_iterator, output_dir=output_dir)
outputs = trainer.evaluate(test_iterator)
avg_BLEU = np.average([out["BLEU"] for out in outputs])
print(f"Relevance Transformer BLEU: {avg_BLEU*100:.2f}")
# Out:
# Writing logs to: conala-retrieval-testing/logs.txt
# HBox(children=(IntProgress(value=0, max=16), HTML(value='')))
# Relevance impact:
# TGT truth:      <sos> text . split ( ',' ) <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['split', 'text', "'s'", "'(?<=\\\\?|!|\\\\.)\\\\s{0,2}(?=[A-Z]|$)'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c']
# Prerdicted text over re
#
# Relevance impact:
# TGT truth:      <sos> type ( v ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['isinstance', 'str', 'return', 'len', 'encode', "'utf-8'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted len over os
#
# Relevance impact:
# TGT truth:      <sos> type ( v ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['isinstance', 'str', 'return', 'len', 'encode', "'utf-8'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted len over os
#
# Relevance impact:
# TGT truth:      <sos> type ( v ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['isinstance', 'str', 'return', 'len', 'encode', "'utf-8'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted len over os
#
# Relevance impact:
# TGT truth:      <sos> type ( v ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['isinstance', 'str', 'return', 'len', 'encode', "'utf-8'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted len over os
#
# Relevance impact:
# TGT truth:      <sos> list ( t ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['tuple', 't', 'tst2', 'str', 'tst', 'zip', '*', '"{s:{c}^{n}}"', 'format', "'dog'"]
# Prerdicted t over list
#
# Relevance impact:
# TGT truth:      <sos> input ( <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'input', '100', 'var']
# Prerdicted input over print
#
# Relevance impact:
# TGT truth:      <sos> sys . path . append ( <unk> ) <eos> <pad> <pad>
# decoded so far: <sos> os .
# RETRIEVAL top words: ['system', "'ulimit -s unlimited; some_executable'", "'script2.py 1'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted system over environ
#
# Relevance impact:
# TGT truth:      <sos> my_list = [ ] <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> <unk> =
# RETRIEVAL top words: ['variable', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'intarray', 'array']
# Prerdicted array over np
#
# Relevance impact:
# TGT truth:      <sos> sys . stdout . write ( '.' ) <eos> <pad> <pad>
# decoded so far: <sos> print ( <unk>
# RETRIEVAL top words: ['format', '"{s:{c}^{n}}"', "'dog'", 'n', '5', 'c', "'x'", '+', 'strip', 'sys']
# Prerdicted + over %
#
# Relevance impact:
# TGT truth:      <sos> list ( t ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> t = tuple (
# RETRIEVAL top words: ['tuple', 't', 'tst2', 'str', 'tst', 'zip', '*', '"{s:{c}^{n}}"', 'format', "'dog'"]
# Prerdicted zip over x
#
# Relevance impact:
# TGT truth:      <sos> getattr ( obj , 'attr' ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['obj', 'hasattr', "'attr_name'", 'getattr', 'your_obj', '__dict__', 'attr', 'my_list_of_objs', '"{s:{c}^{n}}"', 'format']
# Prerdicted obj over print
#
# Relevance impact:
# TGT truth:      <sos> sorted ( d ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['items', 'sorted', 'return', 'dict', 'things', 'iter', 'keys', "'weight'", 'reverse', 'True']
# Prerdicted sorted over sum
#
# Relevance impact:
# TGT truth:      <sos> [ image for <unk> in list_of_menuitems for image in <unk> ] <eos>
# decoded so far: <sos> list_of_menuitems .
# RETRIEVAL top words: ['c', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', "'x'", 'values', 'flatten', 'chain']
# Prerdicted flatten(COPY) over sort
#
# Relevance impact:
# TGT truth:      <sos> level1 = map ( list , level1 ) <eos> <pad> <pad> <pad>
# decoded so far: <sos> list (
# RETRIEVAL top words: ['tst2', 'str', 'tst', '5', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'"]
# Prerdicted str over itertools
#
# Relevance impact:
# TGT truth:      <sos> list2 . <unk> ( list1 ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> list1 = append (
# RETRIEVAL top words: ['zip', 'list1', 'list2', 'append', "'foo'", 'x1', 'x2', 'b', 'len', 'set']
# Prerdicted list2 over list1
#
# Relevance impact:
# TGT truth:      <sos> list ( set ( source_list ) ) <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> <unk> = list (
# RETRIEVAL top words: ['item', 'mynewlist', 'myset', 'set', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c']
# Prerdicted set over source_list
#
# Relevance impact:
# TGT truth:      <sos> d [ <unk> ] = <unk> <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['default_data', "'item3'", '{', '}', 'update', '5', "'item4'", '4', "'item5'", "'name'"]
# Prerdicted { over d
#
# Relevance impact:
# TGT truth:      <sos> l . count ( 'a' ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['L', '"abcdabcva"', 'count', "'ab'", 'y', 'sort', 'operator', 'itemgetter', 'sum', 'isinstance']
# Prerdicted sum over d
#
# Relevance impact:
# TGT truth:      <sos> base64 . <unk> ( bytes ( 'your string' , 'utf-8' ) ) <eos>
# decoded so far: <sos> struct .
# RETRIEVAL top words: ['encode', "'utf8'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'\\xc5\\xc4\\xd6'"]
# Prerdicted encode over unpack
#
# Relevance impact:
# TGT truth:      <sos> os . path . abspath ( 'mydir/myfile.txt' ) <eos> <pad> <pad> <pad>
# decoded so far: <sos> <unk> . open (
# RETRIEVAL top words: ['path', 'realpath', 'getmtime', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted path over 'mydir/myfile.txt'
#
# Relevance impact:
# TGT truth:      <sos> d [ <unk> ] = <unk> <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> { { d . Add
# RETRIEVAL top words: ['default_data', "'item3'", '{', '}', 'update', '5', "'item4'", '4', "'item5'", "'name'"]
# Prerdicted } over (
#
# Relevance impact:
# TGT truth:      <sos> print ( <unk> , file = f ) <eos> <pad> <pad> <pad>
# decoded so far: <sos> f . write ( "hi there" ,
# RETRIEVAL top words: ['write', 'f', "'text to write\\n'", 'file', "'My String\\n'", "'# Data for Class A\\n'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted file over f
#
# Relevance impact:
# TGT truth:      <sos> app . config [ <unk> ] = <unk> <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '*', '10000', 'response']
# Prerdicted response over plt
#
# Relevance impact:
# TGT truth:      <sos> file = open ( <unk> , 'a' ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['open', 'f', "'words.txt'", "'rU'", "'r'", 'output', "'/home/user/test/wsservice/data.pkl'", "'wb'", '"{s:{c}^{n}}"', 'format']
# Prerdicted open over parser
#
# Relevance impact:
# TGT truth:      <sos> subprocess . call ( [ <unk> , <unk> , '/pathto/MyrScript.r' ] ) <eos> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'subprocess', 'call', 'path']
# Prerdicted subprocess over sorted
#
# Relevance impact:
# TGT truth:      <sos> browser . <unk> ( <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> driver .
# RETRIEVAL top words: ['driver', 'execute_script', 'find_element_by_xpath', '"//div[@id=\'a\']//a[@class=\'click\']"', "'window.scrollTo(0, Y)'", "'window.scrollTo(0, document.body.scrollHeight);'", 'find_element_by_id', "'<check_box_id>'", 'is_selected', 'subprocess']
# Prerdicted find_element_by_xpath over <unk>
#
# Relevance impact:
# TGT truth:      <sos> re . split ( <unk> , <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re .
# RETRIEVAL top words: ["' +'", 'split', 'str1', '" "', 'join', 'my_list', 'sub', "' '", '"{s:{c}^{n}}"', 'format']
# Prerdicted sub over findall
#
# Relevance impact:
# TGT truth:      <sos> <unk> . <unk> ( <unk> + filename , open ( filename , 'r' ) ) <eos>
# decoded so far: <sos> <unk> .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'filename', 'ftp', 'open']
# Prerdicted open over form
#
# Relevance impact:
# TGT truth:      <sos> data . update ( a = 1 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> data [ <unk> ] = {
# RETRIEVAL top words: ['default_data', "'item3'", '5', 'update', '{', '}', '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted } over 1
#
# Relevance impact:
# TGT truth:      <sos> len ( list ( yourdict . keys ( ) ) ) <eos> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'len', 'dict_test', 'v']
# Prerdicted len over dict
#
# Relevance impact:
# TGT truth:      <sos> open ( filename , <unk> ) . <unk> ( ) <eos> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['open', "'w'", 'close', "'file.txt'", "'filename'", 'listdir', "'path'", '"{s:{c}^{n}}"', 'format', "'dog'"]
# Prerdicted open over os
#
# Relevance impact:
# TGT truth:      <sos> "" " " "" . join ( list ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['join', '{', '}', 'sort', 'lst', 'map', "''", 'tags', '|', "' '"]
# Prerdicted { over x
#
# Relevance impact:
# TGT truth:      <sos> "" " " "" . join ( list ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ {
# RETRIEVAL top words: ['join', '{', '}', 'sort', 'lst', 'map', "''", 'tags', '|', "' '"]
# Prerdicted ' ' over space
#
# Relevance impact:
# TGT truth:      <sos> <unk> . <unk> . <unk> ( path ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> os . path .
# RETRIEVAL top words: ["'myVar'", 'locals', 'globals', 'pass', 'path', 'exists', "'/etc'"]
# Prerdicted exists over realpath
#
# Relevance impact:
# TGT truth:      <sos> bytes . <unk> ( '4a4b4c' ) . decode ( 'utf-8' ) <eos> <pad> <pad>
# decoded so far: <sos> "" '4a4b4c' "" .
# RETRIEVAL top words: ['decode', "'utf8'", 'stringnamehere', "'utf-8'", "'ignore'", 'content', '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted decode over encode
#
# Relevance impact:
# TGT truth:      <sos> df . reset_index ( level = [ <unk> , <unk> ] ) <eos> <pad>
# decoded so far: <sos> df . set_index (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'index', 'groupby', 'to_csv']
# Prerdicted index over [
#
# Relevance impact:
# TGT truth:      <sos> subprocess . call ( [ <unk> ] ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> soup . find_all ( 'a' , <unk> =
# RETRIEVAL top words: ['subprocess', 'call', "'test.sh otherfunc'", "'test2.py'", "'test1.py'", 'shell', 'True', "'shutdown'", "'/s'", "'test.sh'"]
# Prerdicted True over False
#
# Relevance impact:
# TGT truth:      <sos> ( n for n in [ 1 , 2 , 3 , 5 ] ) <eos>
# decoded so far: <sos>
# RETRIEVAL top words: ['format', '"{s:{c}^{n}}"', "'dog'", 'n', '5', 'c', "'x'", 'datetime', '*', 'range']
# Prerdicted datetime over [
#
# Relevance impact:
# TGT truth:      <sos> list ( dict . keys ( ) ) [ - 1 ] <eos> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'dict', "'Apple'", "'American'"]
# Prerdicted dict over list
#
# Relevance impact:
# TGT truth:      <sos> answer = str ( round ( answer , 2 ) ) <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> int ( answer .
# RETRIEVAL top words: ['round', '005', '8', '7', '6', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5']
# Prerdicted format over decode
#
# Relevance impact:
# TGT truth:      <sos> df [ <unk> ] = df . index <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df . reset_index (
# RETRIEVAL top words: ['reset_index', 'df2', "'a'", 'tolist', '~', 'index', 'duplicated', 'drop', "'column_name'", 'axis']
# Prerdicted drop over )
#
# Relevance impact:
# TGT truth:      <sos> numlist = [ float ( x ) for x in numlist ] <eos> <pad> <pad> <pad>
# decoded so far: <sos> numlist = [ (
# RETRIEVAL top words: ['ord', "'a'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'int']
# Prerdicted int over <unk>
#
# Relevance impact:
# TGT truth:      <sos> re . findall ( <unk> , s ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re . sub ( <unk> ,
# RETRIEVAL top words: ['search', 'findall', "'(?:\\\\w+(?:\\\\s+\\\\w+)*,\\\\s)+(?:\\\\w+(?:\\\\s\\\\w+)*)'", 'sub', "'\\\\((\\\\w+)\\\\)'", "'\\\\1'", 'm', "'\\\\[(\\\\w+)\\\\]'", '"{s:{c}^{n}}"', 'format']
# Prerdicted '\\1' over ''
#
# Relevance impact:
# TGT truth:      <sos> encoded = <unk> . encode ( 'ascii' ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> data = encode . decode (
# RETRIEVAL top words: ['encode', 'data', "'hex'", "'City'", "'ascii'", "'ignore'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted 'hex' over 'utf8'
#
# Relevance impact:
# TGT truth:      <sos> re . findall ( <unk> , text ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re . sub ( <unk> , '' ,
# RETRIEVAL top words: ['doc', 'xpath', '"//a[starts-with(text(),\'some text\')]"', 'split', "'\\\\.\\\\s'", 'text', 'findall', "'(?=(\\\\w\\\\w))'", "'hello'", 'm']
# Prerdicted text over my_string
#
# Relevance impact:
# TGT truth:      <sos> print ( ' ' . join ( map ( str , l ) ) ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['join', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '{', '}']
# Prerdicted { over y
#
# Relevance impact:
# TGT truth:      <sos> print ( re . findall ( <unk> , str ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re .
# RETRIEVAL top words: ['findall', "'(?=(\\\\w\\\\w))'", "'hello'", 'm', 'search', "'\\\\[(\\\\w+)\\\\]'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n']
# Prerdicted findall over sub
#
# Relevance impact:
# TGT truth:      <sos> myList = ',' . join ( map ( str , myList ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> myList = [
# RETRIEVAL top words: ['format', 'int', "','", 'split', '"{0:,.2f}"', '24322', '34', "'1,000,000'", 'replace', "''"]
# Prerdicted '' over i
#
# Relevance impact:
# TGT truth:      <sos> [ x . strip ( ) for x in <unk> . split ( <unk> ) ] <eos> <pad> <pad> <pad>
# decoded so far: <sos> [ s .
# RETRIEVAL top words: ['split', "','", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'rfind']
# Prerdicted split over strip
#
# Relevance impact:
# TGT truth:      <sos> myList = ',' . join ( map ( str , myList ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> myList = [ '' .
# RETRIEVAL top words: ['format', 'int', "','", 'split', '"{0:,.2f}"', '24322', '34', "'1,000,000'", 'replace', "''"]
# Prerdicted split over join
#
# Relevance impact:
# TGT truth:      <sos> urllib . request . <unk> ( url , file_name ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['urllib', 'request', 'urlretrieve', 'file_name', 'wget', 'download', 'file_url', 'system', '\'start "$file"\'', "'http://randomsite.com/file.gz'"]
# Prerdicted file_name(COPY) over url
#
# Relevance impact:
# TGT truth:      <sos> subprocess . <unk> ( <unk> , shell = True ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df .
# RETRIEVAL top words: ['subprocess', 'call', "'test.sh otherfunc'", 'func', '*', 'args', "'tar c my_dir | md5sum'", 'shell', 'True', "'Total score for %s is %s  '"]
# Prerdicted call over set_index
#
# Relevance impact:
# TGT truth:      <sos> "" "({} goals, ${})" "" . format ( self . goals , self . penalties ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> penalties .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '%', 'bool', "'hello there %(5)s'"]
# Prerdicted format over replace
#
# Relevance impact:
# TGT truth:      <sos> my_dict . update ( { 'third_key' : 1 } ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> my_dict .
# RETRIEVAL top words: ['mydict', 'del', 'default_data', "'item3'", 'pop', "'key'", 'None', 'try', 'except', 'KeyError']
# Prerdicted pop over update
#
# Relevance impact:
# TGT truth:      <sos> print ( x . <unk> ( '-' ) [ 0 ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> x [ :
# RETRIEVAL top words: ['-', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'rsplit', "','"]
# Prerdicted - over (
#
# Relevance impact:
# TGT truth:      <sos> os . <unk> ( '/' ) . <unk> - os . <unk> ( '/' ) . <unk> <eos> <pad> <pad> <pad>
# decoded so far: <sos> <unk> . format (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'files', 'sort', 'file_number']
# Prerdicted files over drive
#
# Relevance impact:
# TGT truth:      <sos> my_dict . update ( { 'third_key' : 1 } ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> my_dict . pop (
# RETRIEVAL top words: ['mydict', 'del', 'default_data', "'item3'", 'pop', "'key'", 'None', 'try', 'except', 'KeyError']
# Prerdicted 'key' over 'third_key'
#
# Relevance impact:
# TGT truth:      <sos> [ element for element in lst if not isinstance ( element , str ) ] <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ x for x in
# RETRIEVAL top words: ['lst', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'seq', "'ab'"]
# Prerdicted lst over <unk>
#
# Relevance impact:
# TGT truth:      <sos> <unk> . encode ( <unk> ) . decode ( 'utf-8' ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> "" <unk> "" . encode (
# RETRIEVAL top words: ['encode', "'utf-8'", '"\\\\xc3\\\\x85あ"', 'sys', 'exit', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5']
# Prerdicted 'utf-8' over <unk>
#
# Relevance impact:
# TGT truth:      <sos> [ x for x in myfile . <unk> ( ) if x ! = '' ] <eos> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['f', 'with', 'open', 'as', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c']
# Prerdicted with over map
#
# Relevance impact:
# TGT truth:      <sos> [ x for x in mylist if len ( x ) = = 3 ] <eos> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'mylist', '{', '}']
# Prerdicted { over for
#
# Relevance impact:
# TGT truth:      <sos> datetime . datetime . <unk> ( s ) . strftime ( '%Y-%m-%d %H:%M:%S.%f' ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['datetime', 'strftime', 'time', "'{%Y-%m-%d %H:%M:%S}'", "'%Y-%m-%d %H:%M:%S'", 'strptime', "'2010-11-13 10:33:54.227806'", "'%Y-%m-%d %H:%M:%S.%f'", 'fromtimestamp', 'myNumber']
# Prerdicted datetime over (
#
# Relevance impact:
# TGT truth:      <sos> bool ( re . search ( <unk> , <unk> ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re .
# RETRIEVAL top words: ["''", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sub', "'\\\\w*\\\\d\\\\w*'"]
# Prerdicted sub over findall
#
# Relevance impact:
# TGT truth:      <sos> df [ 'D' ] = df [ 'B' ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df [
# RETRIEVAL top words: ["'b'", "'a'", 'tolist', 'loc', "'column_name'", 'some_value', 'sort', 'ascending', 'True', 'False']
# Prerdicted 'a' over df
#
# Relevance impact:
# TGT truth:      <sos> "" "" "" . join ( [ 'a' , 'b' , 'c' ] ) <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re . sub (
# RETRIEVAL top words: ["'x'", 'c', '5', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'join', "'a'", "'b'"]
# Prerdicted 'a' over [
#
# Relevance impact:
# TGT truth:      <sos> [ mydict [ x ] for x in <unk> ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ x for x in
# RETRIEVAL top words: ['items', 'zip', 'item', 'value', 'dict', 'keys', '*', 'data', 'tup', '"{s:{c}^{n}}"']
# Prerdicted items over r
#
# Relevance impact:
# TGT truth:      <sos> df [ 'D' ] = df [ 'B' ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df [ 'a' ] .
# RETRIEVAL top words: ["'b'", "'a'", 'tolist', 'loc', "'column_name'", 'some_value', 'sort', 'ascending', 'True', 'False']
# Prerdicted tolist over str
#
# Relevance impact:
# TGT truth:      <sos> db . <unk> ( 'SELECT * FROM Schedule WHERE station = $1' , foo . key ( ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> print ( <unk> . format (
# RETRIEVAL top words: ['c', 'random', 'choice', 'foo', 'execute', "'SELECT * FROM foo WHERE bar = %s AND baz = %s'", 'param1', 'param2', '"{s:{c}^{n}}"', 'format']
# Prerdicted foo over GQL
#
# Relevance impact:
# TGT truth:      <sos> "" "" "" . join ( [ 'a' , 'b' , 'c' ] ) <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> re . sub ( 'a' ,
# RETRIEVAL top words: ["'x'", 'c', '5', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'join', "'a'", "'b'"]
# Prerdicted 'b' over 'c'
#
# Relevance impact:
# TGT truth:      <sos> df [ df [ <unk> ] . str . contains ( <unk> ) ] <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> ids = [ ball ] .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'line', 'filter', 'author__id']
# Prerdicted filter over for
#
# Relevance impact:
# TGT truth:      <sos> <unk> ( Derived , <unk> ) . do ( a ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> do . <unk> ( <unk> , Derived ,
# RETRIEVAL top words: ['*', 'super', 'self', '__init__', 'args', 'getattr', 'test', 'a_string', 'ForkedPdb', 'set_trace']
# Prerdicted self over 1
#
# Relevance impact:
# TGT truth:      <sos> [ x for x in myfile . <unk> ( ) if x ! = '' ] <eos> <pad> <pad>
# decoded so far: <sos> with open ( <unk> , 'a' ) as
# RETRIEVAL top words: ['f', 'with', 'open', 'as', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c']
# Prerdicted f over <unk>
#
# Relevance impact:
# TGT truth:      <sos> df . fillna ( df . mean ( axis = 1 ) , axis = 1 ) <eos> <pad>
# decoded so far: <sos> df . groupby ( average = 0 ) .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'fillna', 'mean', 'axis']
# Prerdicted mean over sum
#
# Relevance impact:
# TGT truth:      <sos> df [ df [ 'BoolCol' ] = = True ] . index . tolist ( ) <eos> <pad> <pad>
# decoded so far: <sos> match ( [ 'BoolCol' , <unk> ] ) .
# RETRIEVAL top words: ['data', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'numpy', 'where']
# Prerdicted format over any
#
# Relevance impact:
# TGT truth:      <sos> print ( '\t' . join ( map ( str , list ) ) ) <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> print ( <unk> % ( 1 , 2 ) for
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 't', "'\\t'", 'decode']
# Prerdicted t over val
#
# Relevance impact:
# TGT truth:      <sos> print ( os . path . <unk> ( os . path . <unk> ( 'hemanth.txt' ) ) [ 0 ] ) <eos> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'filename', 'open', "'filename'"]
# Prerdicted open over numpy
#
# Relevance impact:
# TGT truth:      <sos> x = np . <unk> ( x ) . reshape ( 1 , - 1 ) [ ( 0 ) , : ] <eos>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'np', 'array', 'corrcoef']
# Prerdicted np over numpy
#
# Relevance impact:
# TGT truth:      <sos> print ( sum ( row [ column ] for row in data ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['zip', '*', 'sum', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted sum over map
#
# Relevance impact:
# TGT truth:      <sos> data = [ line . strip ( ) for line in open ( 'C:/name/MyDocuments/numbers' , 'r' ) ] <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'f', 'open', 'with']
# Prerdicted with over <unk>
#
# Relevance impact:
# TGT truth:      <sos> my_float = float ( my_string . replace ( ',' , '' ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['format', "','", 'item', '"{s:{c}^{n}}"', "'dog'", 'n', '5', 'c', "'x'", '"{0:,.2f}"']
# Prerdicted item over (
#
# Relevance impact:
# TGT truth:      <sos> list ( dict ( ( x [ 0 ] , x ) for x in L ) . values ( ) ) <eos> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'set', 'woduplicates', 'lseperatedOrblist']
# Prerdicted set over dict
#
# Relevance impact:
# TGT truth:      <sos> print ( <unk> . format ( 1 . 0 / 3 * 100 ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> <unk> .
# RETRIEVAL top words: ['format', '5', '"{s:{c}^{n}}"', "'dog'", 'n', 'c', "'x'", 'webbrowser', 'open', "'file:///my_pdf.pdf'"]
# Prerdicted format over <unk>
#
# Relevance impact:
# TGT truth:      <sos> my_float = float ( my_string . replace ( ',' , '' ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ item .
# RETRIEVAL top words: ['format', "','", 'item', '"{s:{c}^{n}}"', "'dog'", 'n', '5', 'c', "'x'", '"{0:,.2f}"']
# Prerdicted format over strip
#
# Relevance impact:
# TGT truth:      <sos> [ int ( s ) for s in user . split ( ',' ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> user = [
# RETRIEVAL top words: ['split', "','", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'int']
# Prerdicted int over user
#
# Relevance impact:
# TGT truth:      <sos> "" "," "" . join ( trans [ 'category' ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ key for item in a if
# RETRIEVAL top words: ['{', '}', 'join', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted c over item
#
# Relevance impact:
# TGT truth:      <sos> <unk> . sort ( key = lambda row : ( row [ 2 ] , row [ 1 ] ) ) <eos> <pad> <pad>
# decoded so far: <sos> [ set ( t ) for t in set ( <unk> (
# RETRIEVAL top words: ['5', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'", 'item', 'sorted', 'data']
# Prerdicted item over lambda
#
# Relevance impact:
# TGT truth:      <sos> lst = map ( int , open ( <unk> ) . <unk> ( ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sublist', 'filename', 'open']
# Prerdicted open over e
#
# Relevance impact:
# TGT truth:      <sos> self . driver . find_element_by_css_selector ( <unk> ) . <unk> ( <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '+', 'soup', 'super']
# Prerdicted soup over print
#
# Relevance impact:
# TGT truth:      <sos> print ( l [ 3 : ] + l [ : 3 ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['+', 'l', '-', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted l over [
#
# Relevance impact:
# TGT truth:      <sos> [ k for k , v in list ( <unk> ( mylist ) . items ( ) ) if v > 1 ] <eos>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 't', 'mylist', 'del']
# Prerdicted mylist over [
#
# Relevance impact:
# TGT truth:      <sos> print ( concatenate ( ( a , b ) , axis = 0 ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['concatenate', 'axis', 'numpy', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted numpy over np
#
# Relevance impact:
# TGT truth:      <sos> lst = map ( int , open ( <unk> ) . <unk> ( ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> open (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sublist', 'filename', 'open']
# Prerdicted filename over lst
#
# Relevance impact:
# TGT truth:      <sos> sum ( [ pair [ 0 ] for pair in <unk> ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> sum (
# RETRIEVAL top words: ['datetime', 't', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'map']
# Prerdicted map over x
#
# Relevance impact:
# TGT truth:      <sos> print ( l [ 3 : ] + l [ : 3 ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> l = [ ( i
# RETRIEVAL top words: ['+', 'l', '-', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted + over [
#
# Relevance impact:
# TGT truth:      <sos> "" "" "" . join ( [ x for x in <unk> if x . isdigit ( ) ] ) <eos> <pad> <pad> <pad>
# decoded so far: <sos> "" "" "" . join ( [
# RETRIEVAL top words: ['c', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', "'x'", 'sorted', 'zipped', 'max']
# Prerdicted c over i
#
# Relevance impact:
# TGT truth:      <sos> [ k for k , v in list ( <unk> ( mylist ) . items ( ) ) if v > 1 ] <eos>
# decoded so far: <sos> mylist . sort ( key = lambda
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 't', 'mylist', 'del']
# Prerdicted t over x
#
# Relevance impact:
# TGT truth:      <sos> print ( concatenate ( ( a , b ) , axis = 1 ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> np . concatenate ( a [ : ,
# RETRIEVAL top words: ['concatenate', 'axis', 'numpy', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted axis over along
#
# Relevance impact:
# TGT truth:      <sos> max ( k for k , v in x . items ( ) if v ! = 0 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'e', 'max', 'sum']
# Prerdicted max over dict
#
# Relevance impact:
# TGT truth:      <sos> df1 . merge ( df2 , on = 'Date_Time' ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['df2', 'df1', 'pd', 'merge', 'how', 'on', 'index', 's1', "'inner'", "'user_id'"]
# Prerdicted pd over <unk>
#
# Relevance impact:
# TGT truth:      <sos> ( t - datetime . datetime ( 1970 , 1 , 1 ) ) . <unk> ( ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['datetime', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'math', '/']
# Prerdicted datetime over dict
#
# Relevance impact:
# TGT truth:      <sos> list2 = [ x for x in list1 if x ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['zip', 'list1', 'list2', 'x1', 'x2', 'b', 'pair', '-', 'List1', 'List2']
# Prerdicted list1 over contain
#
# Relevance impact:
# TGT truth:      <sos> sorted ( list5 , lambda x : ( <unk> ( x ) , x ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['sorted', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'v', 'alist']
# Prerdicted sorted over list5
#
# Relevance impact:
# TGT truth:      <sos> any ( key . <unk> ( <unk> ) for key in dict1 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['string', 'isdigit', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'any']
# Prerdicted any over print
#
# Relevance impact:
# TGT truth:      <sos> df . replace ( { '\n' : <unk> } , regex = True ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df [
# RETRIEVAL top words: ['replace', 'fillna', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'a'"]
# Prerdicted 'a' over br
#
# Relevance impact:
# TGT truth:      <sos> { i [ 1 ] : i [ 0 ] for i in list ( myDictionary . items ( ) ) } <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict ( (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'v', 'dict', 'zip']
# Prerdicted v over k
#
# Relevance impact:
# TGT truth:      <sos> [ re . sub ( <unk> , ' ' , i ) for i in s ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ int ( x ,
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sub', 'str', "'[^\\\\x00-\\\\x7F]+'"]
# Prerdicted str over 16
#
# Relevance impact:
# TGT truth:      <sos> df1 . merge ( df2 , on = 'Date_Time' ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> pd . merge ( df1 , df2 ,
# RETRIEVAL top words: ['df2', 'df1', 'pd', 'merge', 'how', 'on', 'index', 's1', "'inner'", "'user_id'"]
# Prerdicted on over <unk>
#
# Relevance impact:
# TGT truth:      <sos> df . to_csv ( 'c:\\data\\pandas.txt' , header = None , index = None , sep = ' ' , mode = 'a' ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> <unk> = pd . <unk> ( df .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'write', 'csv', "'mycsv.csv'"]
# Prerdicted write over read
#
# Relevance impact:
# TGT truth:      <sos> l . sort ( key = lambda t : len ( t [ 1 ] ) , reverse = True ) <eos> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> l . sort ( key = lambda x :
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sort', 'len', 'item']
# Prerdicted len over (
#
# Relevance impact:
# TGT truth:      <sos> l = sorted ( l , key = itemgetter ( <unk> ) , reverse = True ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> l . sort ( key = lambda x :
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sorted', 'itemgetter', "'key'"]
# Prerdicted sorted over x
#
# Relevance impact:
# TGT truth:      <sos> df . to_csv ( 'c:\\data\\pandas.txt' , header = None , index = None , sep = ' ' , mode = 'a' ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> <unk> . reset_index ( ) . groupby ( <unk> ) [ 0 ] .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'write', 'csv', "'mycsv.csv'"]
# Prerdicted write over <unk>
#
# Relevance impact:
# TGT truth:      <sos> ( k for k , v in x . items ( ) if v ! = 0 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ list ( i ) for i in set ( tuple ( i ) for i in range ( 0 , len (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'dict', "'Apple'", "'American'"]
# Prerdicted 5 over i
#
# Relevance impact:
# TGT truth:      <sos> open ( 'outfile' , <unk> ) . write ( '#test firstline\n' + open ( 'infile' ) . read ( ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['open', "'w'", 'close', "'file.txt'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c']
# Prerdicted open over with
#
# Relevance impact:
# TGT truth:      <sos> <unk> = sorted ( l , key = itemgetter ( 'name' ) , reverse = True ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['sorted', 'reverse', 'True', 'values', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c']
# Prerdicted sorted over l
#
# Relevance impact:
# TGT truth:      <sos> [ d . strftime ( <unk> ) for d in pandas . <unk> ( <unk> , <unk> ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['datetime', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'Hello %s'", '%']
# Prerdicted datetime over <unk>
#
# Relevance impact:
# TGT truth:      <sos> list ( itertools . combinations ( ( 1 , 2 , 3 ) , 2 ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> tuple (
# RETRIEVAL top words: ['5', 'itertools', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'", 'permutations', '4']
# Prerdicted itertools over i
#
# Relevance impact:
# TGT truth:      <sos> df . loc [ df [ 'Letters' ] = = 'C' , 'Letters' ] . values [ 0 ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df [ df .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'groupby', "'B'", "'User'"]
# Prerdicted groupby over loc
#
# Relevance impact:
# TGT truth:      <sos> "" <unk> "" . join ( s . split ( '.' ) [ : : - 1 ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> "" <unk> "" . join ( [
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'len', 'split', 'item']
# Prerdicted item over 1
#
# Relevance impact:
# TGT truth:      <sos> [ y for x in data for y in ( x if isinstance ( x , list ) else [ x ] ) ] <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> list ( map ( int , [
# RETRIEVAL top words: ['c', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', "'x'", 'j', 'y', 'b']
# Prerdicted j over '1'
#
# Relevance impact:
# TGT truth:      <sos> matrix = [ [ a , b ] , [ c , d ] , [ e , f ] ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> matrix = np . <unk> ( matrix (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '4', 'range', 'A']
# Prerdicted range over 3
#
# Relevance impact:
# TGT truth:      <sos> [ y for x in data for y in ( x if isinstance ( x , list ) else [ x ] ) ] <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> list ( map ( int , [ j ] ,
# RETRIEVAL top words: ['c', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', "'x'", 'j', 'y', 'b']
# Prerdicted y over x
#
# Relevance impact:
# TGT truth:      <sos> result = ( ( a for ( a , b ) in original ) , ( b for ( a , b ) in original ) ) <eos> <pad>
# decoded so far: <sos> list ( map ( lambda x : x , y :
# RETRIEVAL top words: ['n', '"{s:{c}^{n}}"', 'format', "'dog'", '5', 'c', "'x'", '*', 'zip', 'l']
# Prerdicted zip over -
#
# Relevance impact:
# TGT truth:      <sos> [ word for word in mystring . split ( ) if word . <unk> ( <unk> ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> matrix = np . <unk> ( matrix ( range ( 3 ,
# RETRIEVAL top words: ['findall', 'item', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'\\\\[(.*?)\\\\]'"]
# Prerdicted c over 2
#
# Relevance impact:
# TGT truth:      <sos> result = ( ( a for ( a , b ) in original ) , ( b for ( a , b ) in original ) ) <eos> <pad>
# decoded so far: <sos> list ( map ( lambda x : x , y : zip (
# RETRIEVAL top words: ['n', '"{s:{c}^{n}}"', 'format', "'dog'", '5', 'c', "'x'", '*', 'zip', 'l']
# Prerdicted * over a
#
# Relevance impact:
# TGT truth:      <sos> result = ( ( a for ( a , b ) in original ) , ( b for ( a , b ) in original ) ) <eos> <pad>
# decoded so far: <sos> response . loc [ : 4 ( 5 ) for x in range ( <unk> ) ] § <unk> . <unk> (
# RETRIEVAL top words: ['n', '"{s:{c}^{n}}"', 'format', "'dog'", '5', 'c', "'x'", '*', 'zip', 'l']
# Prerdicted n over <unk>
#
# Relevance impact:
# TGT truth:      <sos> max ( k for k , v in x . items ( ) if v ! = 0 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'dict', "'Apple'", "'American'"]
# Prerdicted dict over sorted
#
# Relevance impact:
# TGT truth:      <sos> c = np . <unk> [ ( a [ None , : ] , b [ None , : ] ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'concatenate', 'axis', 'numpy']
# Prerdicted numpy over np
#
# Relevance impact:
# TGT truth:      <sos> <unk> = [ v for i , v in enumerate ( oldlist ) if i not in removelist ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'not', 'element', 'soup']
# Prerdicted element over key
#
# Relevance impact:
# TGT truth:      <sos> "" <unk> "" . replace ( '/' , <unk> ) . split ( <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> "" <unk> "" .
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'result', 'split', "'@'"]
# Prerdicted split over join
#
# Relevance impact:
# TGT truth:      <sos> L = [ int ( '' . join ( [ str ( y ) for y in x ] ) ) for x in L ] <eos> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ map ( int ,
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'int', 'sublist', 'split']
# Prerdicted sublist over x
#
# Relevance impact:
# TGT truth:      <sos> [ x for x in [ <unk> , <unk> , <unk> , <unk> ] if 'X' not in x and 'N' not in x ] <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ { 'X' : a for
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'e', 'next', 'iter']
# Prerdicted c over _
#
# Relevance impact:
# TGT truth:      <sos> scipy . <unk> ( P , T , axes = [ 1 , 1 ] ) . <unk> ( 0 , 1 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> np . <unk> ( <unk> ,
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'T', 'numpy', 'dot']
# Prerdicted T over scipy
#
# Relevance impact:
# TGT truth:      <sos> MyModel . objects . update ( timestamp = <unk> ( <unk> ) + timedelta ( <unk> = <unk> . <unk> ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> MyModel . objects . filter ( <unk> =
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '{', '}', '-']
# Prerdicted { over [
#
# Relevance impact:
# TGT truth:      <sos> c = np . <unk> [ ( a [ None , : ] , b [ None , : ] ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> numpy . concatenate ( a [ : ,
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'concatenate', 'axis', 'numpy']
# Prerdicted axis over along
#
# Relevance impact:
# TGT truth:      <sos> df . <unk> [ np . <unk> ( df [ 'BoolCol' ] ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df . groupby ( df . index [
# RETRIEVAL top words: ['data', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'Value'", 'True']
# Prerdicted True over [
#
# Relevance impact:
# TGT truth:      <sos> print ( '\n' . join ( '\t' . join ( str ( <unk> ) for <unk> in row ) for row in tab ) ) <eos> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> print ( [ '' . join ( <unk> .
# RETRIEVAL top words: ['format', '"{s:{c}^{n}}"', "'dog'", 'n', '5', 'c', "'x'", "'{0:.2f}'", 'your_number', 'join']
# Prerdicted format over <unk>
#
# Relevance impact:
# TGT truth:      <sos> df . replace ( { '\n' : <unk> } , regex = True ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> MyModel . objects . filter ( <unk> = { <unk> :
# RETRIEVAL top words: ["'b'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'a'", 'tolist']
# Prerdicted 'a' over <unk>
#
# Relevance impact:
# TGT truth:      <sos> image = image . <unk> ( ( x , y ) , <unk> . ANTIALIAS ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> MyModel . objects . filter ( <unk> = { width : 'a' } ,
# RETRIEVAL top words: ['Image', 'open', 'show', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'"]
# Prerdicted c over <unk>
#
# Relevance impact:
# TGT truth:      <sos> requests . post ( url , data = DATA , headers = <unk> , <unk> = ( username , password ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['requests', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'post', "'http://httpbin.org/post'"]
# Prerdicted requests over r
#
# Relevance impact:
# TGT truth:      <sos> list . sort ( key = lambda item : ( item [ <unk> ] , item [ <unk> ] ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'sorted', 'items', 't']
# Prerdicted sorted over list
#
# Relevance impact:
# TGT truth:      <sos> [ x for x in sents if not x . <unk> ( <unk> ) and not x . <unk> ( <unk> ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [
# RETRIEVAL top words: ['c', 'item', '_f', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', "'x'", 'str_list']
# Prerdicted item over re
#
# Relevance impact:
# TGT truth:      <sos> df [ 'c' ] = np . where ( df [ 'a' ] . <unk> , df [ 'b' ] , df [ 'a' ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> df [
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'A'", "'B'", "'C'"]
# Prerdicted 'A' over 'a'
#
# Relevance impact:
# TGT truth:      <sos> dict ( x [ i : i + 2 ] for i in range ( 0 , len ( x ) , 2 ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'dict', 'l', 'zip']
# Prerdicted zip over (
#
# Relevance impact:
# TGT truth:      <sos> data [ <unk> ] = data [ <unk> ] . apply ( lambda x : x . weekday ( ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> data [
# RETRIEVAL top words: ["'b'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'a'", 'tolist']
# Prerdicted 'b' over ~
#
# Relevance impact:
# TGT truth:      <sos> print ( dict ( zip ( LD [ 0 ] , zip ( * [ list ( d . values ( ) ) for d in LD ] ) ) ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict ( zip (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'zip', '*', 'list_of_tuples']
# Prerdicted * over keys
#
# Relevance impact:
# TGT truth:      <sos> print ( dict ( zip ( LD [ 0 ] , zip ( * [ list ( d . values ( ) ) for d in LD ] ) ) ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict ( zip ( * [ : : (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'zip', '*', 'list_of_tuples']
# Prerdicted 5 over -
#
# Relevance impact:
# TGT truth:      <sos> re . sub ( <unk> , <unk> , <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> "" _suff "" . replace ( ' ' , '' , c ) . replace (
# RETRIEVAL top words: ['path', '+', "','", 'each', 'f', 'splitext', "'/home/user/somefile.txt'", "'.jpg'", 'replace', "'.'"]
# Prerdicted ',' over 'bar'
#
# Relevance impact:
# TGT truth:      <sos> data [ <unk> ] = data [ <unk> ] . apply ( lambda x : x . weekday ( ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> "" weekday "" . replace ( ' ' , '' , c ) . replace ( ',' ,
# RETRIEVAL top words: ["'b'", '"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'a'", 'tolist']
# Prerdicted 'b' over ':'
#
# Relevance impact:
# TGT truth:      <sos> np . <unk> ( ( [ 1 , 2 , 3 ] , [ 4 , 5 , 6 ] ) ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ list ( a ) for a in zip ( [ 1 , 2 , 3 ] ,
# RETRIEVAL top words: ['5', '4', '6', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'", 'zip']
# Prerdicted 6 over [
#
# Relevance impact:
# TGT truth:      <sos> map ( None , * [ ( 'a' , 1 ) , ( 'b' , 2 ) , ( 'c' , 3 ) , ( 'd' , 4 ) , ( 'e' , ) ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['4', 'dict', 'zip', "'a'", "'b'", "'c'", "'d'", 'b', 'c', '{']
# Prerdicted 'd' over set
#
# Relevance impact:
# TGT truth:      <sos> a [ np . where ( ( a [ : , ( 0 ) ] = = 0 ) * ( a [ : , ( 1 ) ] = = 1 ) ) ] <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", 'data', 'np', "'B'"]
# Prerdicted np over df
#
# Relevance impact:
# TGT truth:      <sos> plt . scatter ( np . random . randn ( 100 ) , np . random . randn ( 100 ) , <unk> = <unk> ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos>
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", '*', 'plt', 'y']
# Prerdicted plt over numpy
#
# Relevance impact:
# TGT truth:      <sos> np . where ( np . in1d ( A , [ 1 , 3 , 4 ] ) . reshape ( A . shape ) , A , 0 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> np .
# RETRIEVAL top words: ['5', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'", 'np', 'A', 'where']
# Prerdicted where over <unk>
#
# Relevance impact:
# TGT truth:      <sos> try : < <unk> > os . <unk> ( path ) < <unk> > except <unk> as exception : < <unk> > if ( exception . <unk> ! = <unk> . <unk> ) : < <unk> > raise <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> if ( path . join (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'myVar'", 'locals', 'globals']
# Prerdicted c over x
#
# Relevance impact:
# TGT truth:      <sos> try : < <unk> > os . <unk> ( path ) < <unk> > except <unk> : < <unk> > if ( not os . path . <unk> ( path ) ) : < <unk> > raise <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> if ( path . join (
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'myVar'", 'locals', 'globals']
# Prerdicted c over x
#
# Relevance impact:
# TGT truth:      <sos> map ( None , * [ ( 'a' , 1 ) , ( 'b' , 2 ) , ( 'c' , 3 ) , ( 'd' , 4 ) , ( 'e' , ) ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> 'd' ( [ 'a' , 'b' , ( [ 'a' ,
# RETRIEVAL top words: ['4', 'dict', 'zip', "'a'", "'b'", "'c'", "'d'", 'b', 'c', '{']
# Prerdicted 'c' over 'b'
#
# Relevance impact:
# TGT truth:      <sos> zip ( * [ ( 'a' , 1 ) , ( 'b' , 2 ) , ( 'c' , 3 ) , ( 'd' , 4 ) ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict ( ( k , v ) for k , v in
# RETRIEVAL top words: ['5', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'", '4', 'dict', 'zip']
# Prerdicted zip over (
#
# Relevance impact:
# TGT truth:      <sos> zip ( * [ ( 'a' , 1 ) , ( 'b' , 2 ) , ( 'c' , 3 ) , ( 'd' , 4 ) , ( 'e' , ) ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict ( [ 'a' , 'b' , ( [ 'a' , 'b' ,
# RETRIEVAL top words: ['4', '5', 'dict', '"{s:{c}^{n}}"', 'format', "'dog'", 'n', 'c', "'x'", 'zip']
# Prerdicted 4 over (
#
# Relevance impact:
# TGT truth:      <sos> try : < <unk> > os . <unk> ( path ) < <unk> > except <unk> as exception : < <unk> > if ( exception . <unk> ! = <unk> . <unk> ) : < <unk> > raise <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> [ [ ( np . arange ( 2 , 3 , 4 ,
# RETRIEVAL top words: ['"{s:{c}^{n}}"', 'format', "'dog'", 'n', '5', 'c', "'x'", "'myVar'", 'locals', 'globals']
# Prerdicted 5 over [
#
# Relevance impact:
# TGT truth:      <sos> map ( None , * [ ( 'a' , 1 ) , ( 'b' , 2 ) , ( 'c' , 3 ) , ( 'd' , 4 ) , ( 'e' , ) ] ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# decoded so far: <sos> dict ( [ 'a' , 'b' , ( [ 'a' , 'b' , 4 ] , [ 'a' , ( [ 'a' , ( 4 , 'd' , ( [ 'a' , ( [ 'a' , ( [ 'a' ,
# RETRIEVAL top words: ['4', 'dict', 'zip', "'a'", "'b'", "'c'", "'d'", 'b', 'c', '{']
# Prerdicted 'c' over (
#
#
# Relevance Transformer BLEU: 22.57

# %% [markdown]
# ## Random parameter sarch

# %%
stop_word_count
